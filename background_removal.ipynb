# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanket-Ghosh/Background-Removal/blob/main/background_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Background Image Change Using PixelLib**

# %%
# !pip3 install pixellib --upgrade

# %%
# !wget https://github.com/ayoolaolafenwa/PixelLib/releases/download/1.1/deeplabv3_xception_tf_dim_ordering_tf_kernels.h5

# %%
import pixellib
from pixellib.tune_bg import alter_bg
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image
from IPython.display import Image as img
from pylab import rcParams

# %%
rcParams['figure.figsize'] = 10, 10

# %%
change_bg = alter_bg()

dir(change_bg)

change_bg.load_pascalvoc_model("deeplabv3_xception_tf_dim_ordering_tf_kernels.h5")

# %%
file_name = "car1.jpg"
bg_file_name = "bgimage.jpg"

# %% [markdown]
# **Original Image**

# %%
plt.imshow(Image.open(file_name))

# %%
plt.imshow(Image.open(bg_file_name))

# %% [markdown]
# **Blur Background**

# %%
change_bg.blur_bg(file_name, moderate = True , output_image_name="blur_img.jpg")

plt.imshow(Image.open("blur_img.jpg"))

# %% [markdown]
# **Grey Background**

# %%
change_bg.gray_bg(file_name, output_image_name="gray_img.jpg")

plt.imshow(Image.open("gray_img.jpg"))

# %% [markdown]
# **Different Background**

# %%
change_bg.change_bg_img(f_image_path = file_name,b_image_path = bg_file_name, output_image_name="new_img.jpg")

plt.imshow(Image.open("new_img.jpg"))

# %%
change_bg.color_bg(file_name, 
                   colors = (123, 123, 123), 
                   output_image_name="colored_bg.jpg")


plt.imshow(Image.open("colored_bg.jpg"))
